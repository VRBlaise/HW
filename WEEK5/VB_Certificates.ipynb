# %% [markdown]
# ![Matplotlib_Certificate-1.png](attachment:Matplotlib_Certificate-1.png)

# %% [markdown]
# ![Pandas_Certificate-1.png](attachment:Pandas_Certificate-1.png)

# %% [markdown]
# ![Seaborn_Certificate-1.png](attachment:Seaborn_Certificate-1.png)

# %% [markdown]
# ![Git_Certificate-1.png](attachment:Git_Certificate-1.png)

# %% [markdown]
# ![Python_Certificate-1.png](attachment:Python_Certificate-1.png)

# %% [markdown]
# ![Shell_Certificate-1.png](attachment:Shell_Certificate-1.png)
