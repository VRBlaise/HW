# %% [markdown]
# ### 1.	Create a python function to scrape Yelp data for 50 restaurants close to you OR Craigslist for the top 50 items of any topic interesting to you. Think about what data you want to scrape aside from the name and location. You must pick at least three other fields. You can use beautiful soup, selenium, scrapy, and/or splinter as possible.

# %%
from bs4 import BeautifulSoup as bs
import pandas as pd
import requests
import time
import csv
import re

# %%
#Save in a file
filename = "YELP_MEXICANS.txt"

f = open(filename, "w")

header = "Rest_Name, Rest_Ratings, Rest_Nofreviews, Rest_Tags"

f.write(header)
# Out:
# 51

# %%
base_url = 'https://www.yelp.com/search?find_desc=Restaurants+-+Mexican&find_loc=Saint+Louis%2C+MO&start='

names = []
ratings = []
reviews = []
restags = []

for i in range(10, 60, 10):
    url = base_url + str(i)
    page=requests.get(url)
    soup = bs(page.text,'html.parser')
    mains = soup.find_all("div", class_="arrange-unit__09f24__rqHTg arrange-unit-fill__09f24__CUubG border-color--default__09f24__NPAKY")
    
    for main in mains:
        try:
            busname = main.find("a", class_="css-1m051bw").text
            names.append(busname)
        except:
            pass  
    
        try:
            rating = main.find("span", {"class" : "display--inline__09f24__c6N_k border-color--default__09f24__NPAKY"}).div.get('aria-label')
            ratings.append(rating)
        except:
            pass
    
        try:
            noreviews = main.find("span", class_="reviewCount__09f24__tnBk4 css-chan6m").text
            reviews.append(noreviews)
        except:
            pass
    
        try:
            tags = main.find_all("p", {"class" : "css-dd1rsv"})
            if len(tags) !=  0:
                tagtext = ''
                for tag in tags:
                    tagtext = tagtext + '  ' + tag.text
                restags.append(tagtext)
        except:
            pass
        #f.write("\n" + busname + "," + rating + "," + noreviews + "," + tagtext)
    
f.close()
# Out:
# Rest_Name: Dos Reyes Mexican Restaurant
# Rest_Noreviews: 199
# Tags:   Mexican  Breakfast & Brunch
# Rest_Name: El Burro Loco
# Rest_Noreviews: 483
# Tags:   Mexican
# Rest_Name: Taqueria El Bronco
# Rest_Noreviews: 253
# Tags:   Mexican
# Rest_Name: El Morelia Super Mercado
# Rest_Noreviews: 32
# Tags:   Mexican
# Rest_Name: La Manganita
# Rest_Noreviews: 6
# Tags:   Mexican
# Rest_Name: Chimi’s Fresh-Mex
# Rest_Noreviews: 128
# Tags:   Mexican  Tex-Mex
# Rest_Name: 3 De Mayo
# Rest_Noreviews: 15
# Tags:   Mexican
# Rest_Name: Uncle Julio’s
# Rest_Noreviews: 143
# Tags:   Tex-Mex  Mexican
# Rest_Name: Más Tequila Cantina
# Rest_Noreviews: 102
# Tags:   Mexican
# Rest_Name: Mi Ranchito
# Rest_Noreviews: 380
# Tags:   Mexican  Bars  Seafood
# Rest_Name: Taqueria Durango
# Rest_Noreviews: 201
# Tags:   Mexican
# Rest_Name: Sunny’s Cantina
# Rest_Noreviews: 88
# Tags:   Burgers  Mexican  Cocktail Bars
# Rest_Name: Lilly’s Panaderia
# Rest_Noreviews: 14
# Tags:   Mexican
# Rest_Name: El Comal
# Rest_Noreviews: 30
# Tags:   Latin American  Tex-Mex
# Rest_Name: El Guanaco
# Rest_Noreviews: 8
# Tags:   Salvadoran  Mexican  Honduran
# Rest_Name: El Toluco Taqueria & Grocery
# Rest_Noreviews: 153
# Tags:   International Grocery  Tacos
# Rest_Name: Diego’s
# Rest_Noreviews: 40
# Tags:   Diners  Mexican
# Rest_Name: Cantina Laredo
# Rest_Noreviews: 197
# Tags:   Mexican  Bars
# Rest_Name: Amigos Cantina
# Rest_Noreviews: 257
# Tags:   Mexican  Bars  Seafood
# Rest_Name: Lily’s Mexican Restaurant
# Rest_Noreviews: 116
# Tags:   Mexican
# Rest_Name: Rosalita’s Cantina
# Rest_Noreviews: 463
# Tags:   Mexican  Cocktail Bars  Tex-Mex
# Rest_Name: Si Señor Mexican Bar and Grill
# Rest_Noreviews: 115
# Tags:   Bars  Mexican
# Rest_Name: Merendero La Catrachitas
# Rest_Noreviews: 22
# Tags:   Latin American  Honduran
# Rest_Name: Hacienda Mexican Restaurant
# Rest_Noreviews: 404
# Tags:   Mexican
# Rest_Name: Mariscos Seafood El Najar
# Rest_Noreviews: 5
# Tags:   Seafood  Mexican
# Rest_Name: Tienda El Ranchito
# Rest_Noreviews: 73
# Tags:   Grocery  Mexican
# Rest_Name: La Fiesta Mexican Resturant
# Rest_Noreviews: 67
# Tags:   Mexican
# Rest_Name: Nixta
# Rest_Noreviews: 205
# Tags:   New Mexican Cuisine  Cocktail Bars
# Rest_Name: La Gloria Mexican Restaurant
# Rest_Noreviews: 8
# Tags:   Mexican  Bars
# Rest_Name: Gauchos Argentinian Steakhouse
# Rest_Noreviews: 120
# Tags:   Argentine  Latin American  Steakhouses
# Rest_Name: Pueblo Solis
# Rest_Noreviews: 251
# Tags:   Mexican
# Rest_Name: El Agave
# Rest_Noreviews: 103
# Tags:   Mexican  Bars  Tex-Mex
# Rest_Name: The Taco and Ice Cream Joint
# Rest_Noreviews: 201
# Tags:   Mexican  Specialty Food  Ice Cream & Frozen Yogurt
# Rest_Name: El Burro Loco Downtown
# Rest_Noreviews: 78
# Tags:   Mexican
# Rest_Name: Las Fuentes
# Rest_Noreviews: 86
# Tags:   Mexican  Bars
# Rest_Name: Mission Taco Joint - Delmar Loop
# Rest_Noreviews: 1022
# Tags:   Mexican  Cocktail Bars  Beer Bar
# Rest_Name: Diablitos Cantina
# Rest_Noreviews: 200
# Tags:   Mexican  Bars
# Rest_Name: El Troquero
# Rest_Noreviews: 24
# Tags:   Mexican
# Rest_Name: King Burrito
# Rest_Noreviews: 94
# Tags:   Mexican  Breakfast & Brunch  Cafes
# Rest_Name: San Jose Mexican Restaurant Webster Groves
# Rest_Noreviews: 79
# Tags:   Tex-Mex
# Rest_Name: San Jose Mexican Restaurant Webster Groves
# Rest_Noreviews: 79
# Tags:   Tex-Mex
# Rest_Name: Tradicional 636
# Rest_Noreviews: 116
# Tags:   Mexican
# Rest_Name: Mi Lupita
# Rest_Noreviews: 191
# Tags:   Mexican  Salad  Bars
# Rest_Name: Hectorito Restaurante
# Rest_Noreviews: 30
# Tags:   Mexican
# Rest_Name: Casa Juarez Mexican Town
# Rest_Noreviews: 126
# Tags:   Mexican  Bars  Seafood
# Rest_Name: Palacios Mexican Restaurant
# Rest_Noreviews: 21
# Tags:   Mexican
# Rest_Name: Taqueria Olvera
# Rest_Noreviews: 192
# Tags:   Mexican
# Rest_Name: Mi Tierra Bonita
# Rest_Noreviews: 48
# Tags:   Mexican
# Rest_Name: Polite Society
# Rest_Noreviews: 808
# Tags:   Bars  American (New)  Breakfast & Brunch
# Rest_Name: Casa Maria Mexican Grill
# Rest_Noreviews: 166
# Tags:   Tacos  Cocktail Bars

# %%
restaurants = {"Rest_Name": names, "Rest_Ratings" : ratings, "Rest_Nofreviews" : reviews, "Rest_Tags" : restags}

# %%
res_df = pd.DataFrame(restaurants)

# %%
res_df
# Out:
#                                      Rest_Name     Rest_Ratings  \
# 0                 Dos Reyes Mexican Restaurant  4.5 star rating
# 1                                El Burro Loco    4 star rating
# 2                           Taqueria El Bronco    4 star rating
# 3                     El Morelia Super Mercado  4.5 star rating
# 4                                 La Manganita    5 star rating
# 5                            Chimi’s Fresh-Mex  4.5 star rating
# 6                                    3 De Mayo  4.5 star rating
# 7                                Uncle Julio’s    3 star rating
# 8                          Más Tequila Cantina    4 star rating
# 9                                  Mi Ranchito    4 star rating
# 10                            Taqueria Durango    4 star rating
# 11                             Sunny’s Cantina  4.5 star rating
# 12                           Lilly’s Panaderia    5 star rating
# 13                                    El Comal    4 star rating
# 14                                  El Guanaco    5 star rating
# 15                El Toluco Taqueria & Grocery  4.5 star rating
# 16                                     Diego’s  3.5 star rating
# 17                              Cantina Laredo  3.5 star rating
# 18                              Amigos Cantina  3.5 star rating
# 19                   Lily’s Mexican Restaurant    4 star rating
# 20                          Rosalita’s Cantina    3 star rating
# 21              Si Señor Mexican Bar and Grill  4.5 star rating
# 22                    Merendero La Catrachitas  4.5 star rating
# 23                 Hacienda Mexican Restaurant    3 star rating
# 24                   Mariscos Seafood El Najar    4 star rating
# 25                          Tienda El Ranchito    4 star rating
# 26                 La Fiesta Mexican Resturant    4 star rating
# 27                                       Nixta    4 star rating
# 28                La Gloria Mexican Restaurant    4 star rating
# 29              Gauchos Argentinian Steakhouse  4.5 star rating
# 30                                Pueblo Solis  3.5 star rating
# 31                                    El Agave  3.5 star rating
# 32                The Taco and Ice Cream Joint  3.5 star rating
# 33                      El Burro Loco Downtown  3.5 star rating
# 34                                 Las Fuentes  3.5 star rating
# 35            Mission Taco Joint - Delmar Loop    4 star rating
# 36                           Diablitos Cantina  3.5 star rating
# 37                                 El Troquero    4 star rating
# 38                                King Burrito  4.5 star rating
# 39  San Jose Mexican Restaurant Webster Groves  3.5 star rating
# 40  San Jose Mexican Restaurant Webster Groves  3.5 star rating
# 41                             Tradicional 636    4 star rating
# 42                                   Mi Lupita    4 star rating
# 43                       Hectorito Restaurante    4 star rating
# 44                    Casa Juarez Mexican Town  3.5 star rating
# 45                 Palacios Mexican Restaurant  4.5 star rating
# 46                             Taqueria Olvera  4.5 star rating
# 47                            Mi Tierra Bonita  4.5 star rating
# 48                              Polite Society  4.5 star rating
# 49                    Casa Maria Mexican Grill  4.5 star rating
#
#    Rest_Nofreviews                                          Rest_Tags
# 0              199                        Mexican  Breakfast & Brunch
# 1              483                                            Mexican
# 2              253                                            Mexican
# 3               32                                            Mexican
# 4                6                                            Mexican
# 5              128                                   Mexican  Tex-Mex
# 6               15                                            Mexican
# 7              143                                   Tex-Mex  Mexican
# 8              102                                            Mexican
# 9              380                             Mexican  Bars  Seafood
# 10             201                                            Mexican
# 11              88                    Burgers  Mexican  Cocktail Bars
# 12              14                                            Mexican
# 13              30                            Latin American  Tex-Mex
# 14               8                      Salvadoran  Mexican  Honduran
# 15             153                       International Grocery  Tacos
# 16              40                                    Diners  Mexican
# 17             197                                      Mexican  Bars
# 18             257                             Mexican  Bars  Seafood
# 19             116                                            Mexican
# 20             463                    Mexican  Cocktail Bars  Tex-Mex
# 21             115                                      Bars  Mexican
# 22              22                           Latin American  Honduran
# 23             404                                            Mexican
# 24               5                                   Seafood  Mexican
# 25              73                                   Grocery  Mexican
# 26              67                                            Mexican
# 27             205                 New Mexican Cuisine  Cocktail Bars
# 28               8                                      Mexican  Bars
# 29             120             Argentine  Latin American  Steakhouses
# 30             251                                            Mexican
# 31             103                             Mexican  Bars  Tex-Mex
# 32             201    Mexican  Specialty Food  Ice Cream & Frozen ...
# 33              78                                            Mexican
# 34              86                                      Mexican  Bars
# 35            1022                   Mexican  Cocktail Bars  Beer Bar
# 36             200                                      Mexican  Bars
# 37              24                                            Mexican
# 38              94                 Mexican  Breakfast & Brunch  Cafes
# 39              79                                            Tex-Mex
# 40              79                                            Tex-Mex
# 41             116                                            Mexican
# 42             191                               Mexican  Salad  Bars
# 43              30                                            Mexican
# 44             126                             Mexican  Bars  Seafood
# 45              21                                            Mexican
# 46             192                                            Mexican
# 47              48                                            Mexican
# 48             808           Bars  American (New)  Breakfast & Brunch
# 49             166                               Tacos  Cocktail Bars

# %%
res_df.to_csv('YELP_MEXICANE.csv', encoding = "UTF-16LE")

# %% [markdown]
# ### 2.	Create a local API that calls your scrape function and stores the data when you call /scrape endpoint. The data you scrape should be viewable when you go to /all .

# %% [markdown]
# Brief and honest: could not make this one work...

# %% [markdown]
# ### 3.	What is web scraping? Why is it helpful? What does it mean for your online presence? Refence the readings and DataCamp.

# %% [markdown]
# Web scraping is the process of collecting structured web data in an automated fashion, that is without the need to manually clicking copying or pasting data from the source pages. Using web scraping we can do sentimental analysis over social media on our favorite politicians or stocks,  price or news monitoring,  market research or anything else that requires data accessible on the internet. Most importantly it is able to provide the data in a structured manner. As for our online presence, implications are twofold: we ant to be prudent to escape our own data being misused as well as we should be ethical in using web scaping in accordance to the wishes of the webpage owners.
