# %% [markdown]
# ### 1.	Perform pre-processing on the full dataset here: https://www.kaggle.com/sohier/calcofi

# %%
import pandas as pd

bottle = pd.read_csv('C:/Users/balazs.varga/Documents/BALAZS/USE/REPOS/CalCOFI/bottle.csv', low_memory = False)
cast = pd.read_csv('C:/Users/balazs.varga/Documents/BALAZS/USE/REPOS/CalCOFI/cast.csv', low_memory = False)

# %%
bottle.head(1)
# Out:
#    Cst_Cnt  Btl_Cnt       Sta_ID                                Depth_ID  \
# 0        1        1  054.0 056.0  19-4903CR-HY-060-0930-05400560-0000A-3
#
#    Depthm  T_degC  Salnty  O2ml_L  STheta  O2Sat  ...  R_PHAEO  R_PRES  \
# 0       0    10.5   33.44     NaN  25.649    NaN  ...      NaN       0
#
#    R_SAMP  DIC1  DIC2  TA1  TA2  pH2  pH1  DIC Quality Comment
# 0     NaN   NaN   NaN  NaN  NaN  NaN  NaN                  NaN
#
# [1 rows x 74 columns]

# %%
bottle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 864863 entries, 0 to 864862
# Data columns (total 74 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Cst_Cnt              864863 non-null  int64
#  1   Btl_Cnt              864863 non-null  int64
#  2   Sta_ID               864863 non-null  object
#  3   Depth_ID             864863 non-null  object
#  4   Depthm               864863 non-null  int64
#  5   T_degC               853900 non-null  float64
#  6   Salnty               817509 non-null  float64
#  7   O2ml_L               696201 non-null  float64
#  8   STheta               812174 non-null  float64
#  9   O2Sat                661274 non-null  float64
#  10  Oxy_µmol/Kg          661268 non-null  float64
#  11  BtlNum               118667 non-null  float64
#  12  RecInd               864863 non-null  int64
#  13  T_prec               853900 non-null  float64
#  14  T_qual               23127 non-null   float64
#  15  S_prec               817509 non-null  float64
#  16  S_qual               74914 non-null   float64
#  17  P_qual               673755 non-null  float64
#  18  O_qual               184676 non-null  float64
#  19  SThtaq               65823 non-null   float64
#  20  O2Satq               217797 non-null  float64
#  21  ChlorA               225272 non-null  float64
#  22  Chlqua               639166 non-null  float64
#  23  Phaeop               225271 non-null  float64
#  24  Phaqua               639170 non-null  float64
#  25  PO4uM                413317 non-null  float64
#  26  PO4q                 451786 non-null  float64
#  27  SiO3uM               354091 non-null  float64
#  28  SiO3qu               510866 non-null  float64
#  29  NO2uM                337576 non-null  float64
#  30  NO2q                 529474 non-null  float64
#  31  NO3uM                337403 non-null  float64
#  32  NO3q                 529933 non-null  float64
#  33  NH3uM                64962 non-null   float64
#  34  NH3q                 808299 non-null  float64
#  35  C14As1               14432 non-null   float64
#  36  C14A1p               12760 non-null   float64
#  37  C14A1q               848605 non-null  float64
#  38  C14As2               14414 non-null   float64
#  39  C14A2p               12742 non-null   float64
#  40  C14A2q               848623 non-null  float64
#  41  DarkAs               22649 non-null   float64
#  42  DarkAp               20457 non-null   float64
#  43  DarkAq               840440 non-null  float64
#  44  MeanAs               22650 non-null   float64
#  45  MeanAp               20457 non-null   float64
#  46  MeanAq               840439 non-null  float64
#  47  IncTim               14437 non-null   object
#  48  LightP               18651 non-null   float64
#  49  R_Depth              864863 non-null  float64
#  50  R_TEMP               853900 non-null  float64
#  51  R_POTEMP             818816 non-null  float64
#  52  R_SALINITY           817509 non-null  float64
#  53  R_SIGMA              812007 non-null  float64
#  54  R_SVA                812092 non-null  float64
#  55  R_DYNHT              818206 non-null  float64
#  56  R_O2                 696201 non-null  float64
#  57  R_O2Sat              666448 non-null  float64
#  58  R_SIO3               354099 non-null  float64
#  59  R_PO4                413325 non-null  float64
#  60  R_NO3                337411 non-null  float64
#  61  R_NO2                337584 non-null  float64
#  62  R_NH4                64982 non-null   float64
#  63  R_CHLA               225276 non-null  float64
#  64  R_PHAEO              225275 non-null  float64
#  65  R_PRES               864863 non-null  int64
#  66  R_SAMP               122006 non-null  float64
#  67  DIC1                 1999 non-null    float64
#  68  DIC2                 224 non-null     float64
#  69  TA1                  2084 non-null    float64
#  70  TA2                  234 non-null     float64
#  71  pH2                  10 non-null      float64
#  72  pH1                  84 non-null      float64
#  73  DIC Quality Comment  55 non-null      object
# dtypes: float64(65), int64(5), object(4)
# memory usage: 488.3+ MB

# %%
cast.head(1)
# Out:
#    Cst_Cnt          Cruise_ID  Cruise        Cruz_Sta  DbSta_ID  \
# 0        1  1949-03-01-C-31CR  194903  19490305400560   5400560
#
#                           Cast_ID       Sta_ID  Quarter Sta_Code  Distance  \
# 0  19-4903CR-HY-060-0930-05400560  054.0 056.0        1      NST       NaN
#
#    ... Wave_Prd  Wind_Dir  Wind_Spd  Barometer  Dry_T Wet_T  Wea  Cloud_Typ  \
# 0  ...      NaN      23.0      18.0        NaN    NaN   NaN  2.0        NaN
#
#    Cloud_Amt Visibility
# 0        NaN        NaN
#
# [1 rows x 61 columns]

# %%
cast.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34404 entries, 0 to 34403
# Data columns (total 61 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Cst_Cnt      34404 non-null  int64
#  1   Cruise_ID    34404 non-null  object
#  2   Cruise       34404 non-null  int64
#  3   Cruz_Sta     34404 non-null  int64
#  4   DbSta_ID     34404 non-null  int64
#  5   Cast_ID      34404 non-null  object
#  6   Sta_ID       34404 non-null  object
#  7   Quarter      34404 non-null  int64
#  8   Sta_Code     34404 non-null  object
#  9   Distance     19714 non-null  float64
#  10  Date         34404 non-null  object
#  11  Year         34404 non-null  int64
#  12  Month        34404 non-null  int64
#  13  Julian_Date  34404 non-null  int64
#  14  Julian_Day   34404 non-null  int64
#  15  Time         34080 non-null  object
#  16  Lat_Dec      34404 non-null  float64
#  17  Lat_Deg      34404 non-null  int64
#  18  Lat_Min      34404 non-null  float64
#  19  Lat_Hem      34404 non-null  object
#  20  Lon_Dec      34404 non-null  float64
#  21  Lon_Deg      34404 non-null  int64
#  22  Lon_Min      34404 non-null  float64
#  23  Lon_Hem      34404 non-null  object
#  24  Rpt_Line     34404 non-null  float64
#  25  St_Line      34404 non-null  float64
#  26  Ac_Line      34404 non-null  float64
#  27  Rpt_Sta      34404 non-null  float64
#  28  St_Station   34404 non-null  float64
#  29  Ac_Sta       34404 non-null  float64
#  30  Bottom_D     32123 non-null  float64
#  31  Secchi       5263 non-null   float64
#  32  ForelU       2077 non-null   float64
#  33  Ship_Name    32714 non-null  object
#  34  Ship_Code    34404 non-null  object
#  35  Data_Type    34404 non-null  object
#  36  Order_Occ    9954 non-null   float64
#  37  Event_Num    34401 non-null  float64
#  38  Cruz_Leg     1464 non-null   float64
#  39  Orig_Sta_ID  34404 non-null  object
#  40  Data_Or      18275 non-null  object
#  41  Cruz_Num     34404 non-null  object
#  42  IntChl       12203 non-null  float64
#  43  IntC14       2129 non-null   float64
#  44  Inc_Str      2133 non-null   object
#  45  Inc_End      2133 non-null   object
#  46  PST_LAN      2117 non-null   object
#  47  Civil_T      2116 non-null   object
#  48  TimeZone     4782 non-null   float64
#  49  Wave_Dir     12558 non-null  float64
#  50  Wave_Ht      12098 non-null  float64
#  51  Wave_Prd     11634 non-null  float64
#  52  Wind_Dir     32928 non-null  float64
#  53  Wind_Spd     32725 non-null  float64
#  54  Barometer    19063 non-null  float64
#  55  Dry_T        19071 non-null  float64
#  56  Wet_T        18989 non-null  float64
#  57  Wea          26807 non-null  float64
#  58  Cloud_Typ    9920 non-null   float64
#  59  Cloud_Amt    11882 non-null  float64
#  60  Visibility   9507 non-null   float64
# dtypes: float64(32), int64(11), object(18)
# memory usage: 16.0+ MB

# %%
print('bottle data:')
print('............')
print(bottle.isna().sum())
print('----------------------------------------')
print('cast data:')
print('...............')
print(cast.isna().sum())
# Out:
# bottle data:
# ............
# Cst_Cnt                     0
# Btl_Cnt                     0
# Sta_ID                      0
# Depth_ID                    0
# Depthm                      0
#                         ...
# TA1                    862779
# TA2                    864629
# pH2                    864853
# pH1                    864779
# DIC Quality Comment    864808
# Length: 74, dtype: int64
# ----------------------------------------
# cast data:
# ...............
# Cst_Cnt           0
# Cruise_ID         0
# Cruise            0
# Cruz_Sta          0
# DbSta_ID          0
#               ...
# Wet_T         15415
# Wea            7597
# Cloud_Typ     24484
# Cloud_Amt     22522
# Visibility    24897
# Length: 61, dtype: int64

# %%
columns = bottle.columns

for column in columns:
    print(column + ':')
    print('.................')
    print(bottle[column].value_counts())
    print('----------------------------------------')
# Out:
# Cst_Cnt:
# .................
# 14467    80
# 14083    79
# 13957    78
# 14082    78
# 12467    76
#          ..
# 24167     1
# 24168     1
# 24169     1
# 24170     1
# 22983     1
# Name: Cst_Cnt, Length: 34404, dtype: int64
# ----------------------------------------
# Btl_Cnt:
# .................
# 1         1
# 576594    1
# 576570    1
# 576571    1
# 576572    1
#          ..
# 288292    1
# 288293    1
# 288294    1
# 288295    1
# 864863    1
# Name: Btl_Cnt, Length: 864863, dtype: int64
# ----------------------------------------
# Sta_ID:
# .................
# 090.0 045.0    10043
# 090.0 070.0    10039
# 090.0 037.0     9771
# 090.0 060.0     9521
# 080.0 060.0     9393
#                ...
# 102.0 035.0        1
# 101.0 040.0        1
# 101.0 035.0        1
# 106.0 030.5        1
# 101.0 045.0        1
# Name: Sta_ID, Length: 2634, dtype: int64
# ----------------------------------------
# Depth_ID:
# .................
# 20-16045S-MX-110-2018-06330900-0010A-3    2
# 20-16045S-MX-110-1421-06670900-0061A-3    2
# 20-16045S-MX-110-2018-06330900-0025A-3    2
# 20-16045S-MX-110-2018-06330900-0088A-3    2
# 20-16045S-MX-110-2018-06330900-0002A-3    2
#                                          ..
# 19-5907PT-HY-194-0242-08330900-0106A-3    1
# 19-5907PT-HY-194-0242-08330900-0124A-3    1
# 19-5907PT-HY-194-0242-08330900-0125A-7    1
# 19-5907PT-HY-194-0242-08330900-0141A-3    1
# 20-1611SR-MX-310-2239-09340264-0015A-3    1
# Name: Depth_ID, Length: 864850, dtype: int64
# ----------------------------------------
# Depthm:
# .................
# 10      35104
# 20      33573
# 0       33410
# 30      33208
# 50      32506
#         ...
# 2188        1
# 2918        1
# 1851        1
# 2621        1
# 2882        1
# Name: Depthm, Length: 3219, dtype: int64
# ----------------------------------------
# T_degC:
# .................
# 9.100     1115
# 9.020     1107
# 8.880     1102
# 9.300     1097
# 9.060     1087
#           ...
# 6.864        1
# 19.281       1
# 15.233       1
# 5.484        1
# 17.533       1
# Name: T_degC, Length: 13847, dtype: int64
# ----------------------------------------
# Salnty:
# .................
# 33.5800    3953
# 33.5700    3239
# 33.5500    3187
# 33.4800    3171
# 34.3400    3022
#            ...
# 33.5862       1
# 33.4486       1
# 33.8625       1
# 33.9142       1
# 33.4218       1
# Name: Salnty, Length: 14602, dtype: int64
# ----------------------------------------
# O2ml_L:
# .................
# 5.800    2876
# 5.760    2821
# 5.840    2771
# 5.790    2754
# 5.740    2724
#          ...
# 4.193       1
# 6.244       1
# 0.942       1
# 1.506       1
# 6.355       1
# Name: O2ml_L, Length: 6500, dtype: int64
# ----------------------------------------
# STheta:
# .................
# 26.97900    488
# 26.99500    472
# 26.96900    468
# 26.62000    464
# 26.63000    462
#            ...
# 26.80614      1
# 26.65225      1
# 26.60019      1
# 26.57912      1
# 24.15297      1
# Name: STheta, Length: 36368, dtype: int64
# ----------------------------------------
# O2Sat:
# .................
# 102.40    2740
# 102.60    2666
# 102.50    2644
# 102.30    2618
# 102.20    2602
#           ...
# 65.91        1
# 92.84        1
# 56.25        1
# 34.49        1
# 108.46       1
# Name: O2Sat, Length: 10379, dtype: int64
# ----------------------------------------
# Oxy_µmol/Kg:
# .................
# 0.00000      53
# 16.52491     21
# 21.30864     20
# 16.09000     19
# 15.65495     19
#              ..
# 226.64050     1
# 225.33280     1
# 225.30710     1
# 225.29150     1
# 31.34000      1
# Name: Oxy_µmol/Kg, Length: 391814, dtype: int64
# ----------------------------------------
# BtlNum:
# .................
# 3.0     6482
# 1.0     6468
# 2.0     6450
# 4.0     6439
# 5.0     6299
# 6.0     6110
# 7.0     6042
# 8.0     5923
# 9.0     5765
# 10.0    5611
# 11.0    5529
# 12.0    5417
# 13.0    5185
# 14.0    5133
# 15.0    5129
# 16.0    5054
# 17.0    5017
# 18.0    4983
# 19.0    4954
# 20.0    4859
# 21.0    2634
# 22.0    1494
# 23.0     967
# 24.0     651
# 0.0       69
# 25.0       3
# Name: BtlNum, dtype: int64
# ----------------------------------------
# RecInd:
# .................
# 3    455956
# 7    324795
# 5     81009
# 6      3101
# 4         2
# Name: RecInd, dtype: int64
# ----------------------------------------
# T_prec:
# .................
# 2.0    834819
# 3.0     16862
# 1.0      2219
# Name: T_prec, dtype: int64
# ----------------------------------------
# T_qual:
# .................
# 6.0    11589
# 9.0    10963
# 8.0      575
# Name: T_qual, dtype: int64
# ----------------------------------------
# S_prec:
# .................
# 3.0    585980
# 2.0    231529
# Name: S_prec, dtype: int64
# ----------------------------------------
# S_qual:
# .................
# 9.0    47354
# 6.0    25735
# 8.0     1825
# Name: S_qual, dtype: int64
# ----------------------------------------
# P_qual:
# .................
# 9.0    673754
# 6.0         1
# Name: P_qual, dtype: int64
# ----------------------------------------
# O_qual:
# .................
# 9.0    168662
# 6.0     14559
# 8.0      1455
# Name: O_qual, dtype: int64
# ----------------------------------------
# SThtaq:
# .................
# 9.0    52692
# 6.0    10976
# 8.0     2155
# Name: SThtaq, dtype: int64
# ----------------------------------------
# O2Satq:
# .................
# 9.0    203557
# 6.0      9690
# 8.0      2657
# 2.0      1893
# Name: O2Satq, dtype: int64
# ----------------------------------------
# ChlorA:
# .................
# 0.010    17321
# 0.000    12575
# 0.020     8733
# 0.030     6178
# 0.090     5532
#          ...
# 1.735        1
# 7.547        1
# 6.144        1
# 1.406        1
# 2.118        1
# Name: ChlorA, Length: 3458, dtype: int64
# ----------------------------------------
# Chlqua:
# .................
# 9.0    639069
# 8.0        97
# Name: Chlqua, dtype: int64
# ----------------------------------------
# Phaeop:
# .................
# 0.030     14868
# 0.040     14234
# 0.050     12867
# 0.020     12428
# 0.060     10578
#           ...
# 18.910        1
# 1.486         1
# 3.290         1
# 4.610         1
# 0.616         1
# Name: Phaeop, Length: 1649, dtype: int64
# ----------------------------------------
# Phaqua:
# .................
# 9.0    639070
# 8.0       100
# Name: Phaqua, dtype: int64
# ----------------------------------------
# PO4uM:
# .................
# 0.32    6215
# 0.33    5915
# 0.34    5900
# 0.35    5844
# 0.31    5661
#         ...
# 4.31       1
# 4.55       1
# 4.37       1
# 4.38       1
# 4.28       1
# Name: PO4uM, Length: 451, dtype: int64
# ----------------------------------------
# PO4q:
# .................
# 9.0    451483
# 8.0       302
# 4.0         1
# Name: PO4q, dtype: int64
# ----------------------------------------
# SiO3uM:
# .................
# 2.00     9428
# 3.00     6376
# 2.40     4232
# 2.50     4218
# 1.00     4046
#          ...
# 51.15       1
# 80.27       1
# 68.32       1
# 55.82       1
# 65.77       1
# Name: SiO3uM, Length: 8691, dtype: int64
# ----------------------------------------
# SiO3qu:
# .................
# 9.0    510710
# 8.0       155
# 4.0         1
# Name: SiO3qu, dtype: int64
# ----------------------------------------
# NO2uM:
# .................
# 0.000    137707
# 0.010     64276
# 0.020     29335
# 0.030     15280
# 0.040      9639
#           ...
# 0.357         1
# 1.850         1
# 1.940         1
# 2.060         1
# 0.319         1
# Name: NO2uM, Length: 690, dtype: int64
# ----------------------------------------
# NO2q:
# .................
# 9.0    527225
# 8.0      2210
# 4.0        39
# Name: NO2q, dtype: int64
# ----------------------------------------
# NO3uM:
# .................
# 0.00     42917
# 0.10     22397
# 0.20      8484
# 0.30      3806
# 0.40      2301
#          ...
# 8.09         1
# 24.65        1
# 41.98        1
# 10.15        1
# 41.37        1
# Name: NO3uM, Length: 3680, dtype: int64
# ----------------------------------------
# NO3q:
# .................
# 9.0    527398
# 8.0      2257
# 4.0       277
# 6.0         1
# Name: NO3q, dtype: int64
# ----------------------------------------
# NH3uM:
# .................
# 0.00    32722
# 0.01     3686
# 0.02     3228
# 0.03     2742
# 0.04     2486
#         ...
# 5.17        1
# 5.16        1
# 3.56        1
# 3.18        1
# 3.24        1
# Name: NH3uM, Length: 316, dtype: int64
# ----------------------------------------
# NH3q:
# .................
# 9.0    799839
# 4.0      8460
# Name: NH3q, dtype: int64
# ----------------------------------------
# C14As1:
# .................
# 1.400    248
# 1.500    241
# 1.200    236
# 1.100    233
# 1.300    222
#         ...
# 3.546      1
# 3.617      1
# 5.168      1
# 3.822      1
# 0.211      1
# Name: C14As1, Length: 2175, dtype: int64
# ----------------------------------------
# C14A1p:
# .................
# 1.0    9354
# 2.0    3406
# Name: C14A1p, dtype: int64
# ----------------------------------------
# C14A1q:
# .................
# 9.0    848598
# 8.0         7
# Name: C14A1q, dtype: int64
# ----------------------------------------
# C14As2:
# .................
# 1.500     231
# 1.300     225
# 1.200     221
# 1.600     218
# 1.400     216
#          ...
# 1.181       1
# 3.049       1
# 12.607      1
# 13.569      1
# 0.217       1
# Name: C14As2, Length: 2176, dtype: int64
# ----------------------------------------
# C14A2p:
# .................
# 1.0    9330
# 2.0    3412
# Name: C14A2p, dtype: int64
# ----------------------------------------
# C14A2q:
# .................
# 9.0    848616
# 8.0         7
# Name: C14A2q, dtype: int64
# ----------------------------------------
# DarkAs:
# .................
# 0.070    1328
# 0.060    1320
# 0.050    1299
# 0.080    1255
# 0.040    1231
#          ...
# 0.018       1
# 0.009       1
# 0.027       1
# 0.033       1
# 0.239       1
# Name: DarkAs, Length: 728, dtype: int64
# ----------------------------------------
# DarkAp:
# .................
# 2.0    20323
# 1.0      134
# Name: DarkAp, dtype: int64
# ----------------------------------------
# DarkAq:
# .................
# 9.0    840433
# 8.0         7
# Name: DarkAq, dtype: int64
# ----------------------------------------
# MeanAs:
# .................
# 1.500     452
# 1.400     414
# 1.100     406
# 1.300     404
# 1.200     378
#          ...
# 16.567      1
# 26.854      1
# 30.590      1
# 39.600      1
# 0.761       1
# Name: MeanAs, Length: 2681, dtype: int64
# ----------------------------------------
# MeanAp:
# .................
# 1.0    15208
# 2.0     5249
# Name: MeanAp, dtype: int64
# ----------------------------------------
# MeanAq:
# .................
# 9.0    840432
# 8.0         7
# Name: MeanAq, dtype: int64
# ----------------------------------------
# IncTim:
# .................
# 12/30/1899 05:45:00    325
# 12/30/1899 05:50:00    284
# 12/30/1899 05:35:00    232
# 12/30/1899 05:40:00    227
# 12/30/1899 05:55:00    226
#                       ...
# 12/30/1899 03:30:00      6
# 12/30/1899 03:48:00      6
# 12/30/1899 05:01:00      6
# 12/30/1899 05:13:00      6
# 12/30/1899 08:33:00      6
# Name: IncTim, Length: 199, dtype: int64
# ----------------------------------------
# LightP:
# .................
# 0.00     552
# 0.93     511
# 0.01     379
# 0.02     363
# 0.04     349
#         ...
# 83.00      1
# 82.20      1
# 43.60      1
# 75.40      1
# 60.60      1
# Name: LightP, Length: 1149, dtype: int64
# ----------------------------------------
# R_Depth:
# .................
# 10.0      35225
# 20.0      33573
# 0.0       33410
# 30.0      33212
# 50.0      32509
#           ...
# 2865.0        1
# 3055.0        1
# 3247.0        1
# 1366.0        1
# 2882.0        1
# Name: R_Depth, Length: 3219, dtype: int64
# ----------------------------------------
# R_TEMP:
# .................
# 9.10     1157
# 8.88     1144
# 9.02     1140
# 8.90     1138
# 9.30     1135
#          ...
# 28.73       1
# 28.95       1
# 29.04       1
# 30.58       1
# 29.67       1
# Name: R_TEMP, Length: 2819, dtype: int64
# ----------------------------------------
# R_POTEMP:
# .................
# 9.27     1038
# 9.00     1033
# 9.08     1023
# 8.74     1008
# 8.86     1008
#          ...
# 26.73       1
# 28.80       1
# 29.81       1
# 30.18       1
# 30.13       1
# Name: R_POTEMP, Length: 2857, dtype: int64
# ----------------------------------------
# R_SALINITY:
# .................
# 33.580    4003
# 33.570    3307
# 33.550    3266
# 33.480    3224
# 33.490    3073
#           ...
# 35.573       1
# 35.532       1
# 35.528       1
# 35.594       1
# 32.396       1
# Name: R_SALINITY, Length: 3584, dtype: int64
# ----------------------------------------
# R_SIGMA:
# .................
# 26.970    3950
# 26.600    3921
# 26.980    3880
# 26.610    3876
# 26.590    3855
#           ...
# 27.317       1
# 27.257       1
# 27.078       1
# 27.305       1
# 23.643       1
# Name: R_SIGMA, Length: 4398, dtype: int64
# ----------------------------------------
# R_SVA:
# .................
# 146.9    534
# 146.0    530
# 153.9    527
# 146.5    525
# 150.5    513
#         ...
# 522.6      1
# 535.5      1
# 39.9       1
# 38.8       1
# 546.2      1
# Name: R_SVA, Length: 5254, dtype: int64
# ----------------------------------------
# R_DYNHT:
# .................
# 0.000    32523
# 0.030    25549
# 0.060    15315
# 0.090    13122
# 0.070    12446
#          ...
# 1.545        1
# 1.478        1
# 1.408        1
# 1.258        1
# 2.241        1
# Name: R_DYNHT, Length: 1848, dtype: int64
# ----------------------------------------
# R_O2:
# .................
# 5.80    3023
# 5.76    3007
# 5.84    2935
# 5.77    2906
# 5.79    2904
#         ...
# 8.41       1
# 7.94       1
# 8.16       1
# 8.09       1
# 8.66       1
# Name: R_O2, Length: 871, dtype: int64
# ----------------------------------------
# R_O2Sat:
# .................
# 102.4    2890
# 102.5    2816
# 102.2    2813
# 102.6    2793
# 102.3    2792
#          ...
# 137.9       1
# 133.7       1
# 138.5       1
# 162.4       1
# 134.3       1
# Name: R_O2Sat, Length: 1453, dtype: int64
# ----------------------------------------
# R_SIO3:
# .................
# 2.0      9992
# 3.0      6582
# 2.4      4568
# 2.5      4512
# 2.1      4490
#          ...
# 148.8       1
# 154.2       1
# 182.4       1
# 176.2       1
# 170.8       1
# Name: R_SIO3, Length: 1784, dtype: int64
# ----------------------------------------
# R_PO4:
# .................
# 0.32    6218
# 0.33    5915
# 0.34    5899
# 0.35    5844
# 0.31    5661
#         ...
# 4.31       1
# 4.55       1
# 4.37       1
# 4.38       1
# 4.28       1
# Name: R_PO4, Length: 451, dtype: int64
# ----------------------------------------
# R_NO3:
# .................
#  0.0     43246
#  0.1     23160
#  0.2      8620
#  0.3      3920
#  0.4      2390
#          ...
#  48.0        1
#  50.6        1
#  50.4        1
#  48.2        1
# -0.1         1
# Name: R_NO3, Length: 506, dtype: int64
# ----------------------------------------
# R_NO2:
# .................
# 0.00    138113
# 0.01     67971
# 0.02     32163
# 0.03     16686
# 0.04     10294
#          ...
# 1.17         1
# 2.30         1
# 2.23         1
# 1.32         1
# 1.43         1
# Name: R_NO2, Length: 208, dtype: int64
# ----------------------------------------
# R_NH4:
# .................
# 0.00    32741
# 0.01     3683
# 0.02     3229
# 0.03     2741
# 0.04     2487
#         ...
# 5.17        1
# 5.16        1
# 3.56        1
# 3.18        1
# 3.24        1
# Name: R_NH4, Length: 316, dtype: int64
# ----------------------------------------
# R_CHLA:
# .................
# 0.01     19199
# 0.00     14082
# 0.02      9614
# 0.03      6796
# 0.09      5956
#          ...
# 11.84        1
# 11.03        1
# 8.64         1
# 8.77         1
# 10.71        1
# Name: R_CHLA, Length: 1373, dtype: int64
# ----------------------------------------
# R_PHAEO:
# .................
# 0.03     16677
# 0.04     15918
# 0.05     14102
# 0.02     13794
# 0.06     11690
#          ...
# 9.83         1
# 8.83         1
# 14.56        1
# 14.91        1
# 4.02         1
# Name: R_PHAEO, Length: 547, dtype: int64
# ----------------------------------------
# R_PRES:
# .................
# 10      35250
# 20      33573
# 0       33410
# 30      33213
# 50      32509
#         ...
# 3907        1
# 4154        1
# 4402        1
# 1548        1
# 2648        1
# Name: R_PRES, Length: 3328, dtype: int64
# ----------------------------------------
# R_SAMP:
# .................
# 203.0    4806
# 201.0    4790
# 202.0    4773
# 204.0    4768
# 205.0    4717
#          ...
# 414.0       1
# 421.0       1
# 422.0       1
# 423.0       1
# 0.0         1
# Name: R_SAMP, Length: 74, dtype: int64
# ----------------------------------------
# DIC1:
# .................
# 2014.58    3
# 2014.82    2
# 1998.46    2
# 2003.40    2
# 2010.47    2
#           ..
# 2011.63    1
# 2311.19    1
# 2269.50    1
# 2235.07    1
# 2296.50    1
# Name: DIC1, Length: 1928, dtype: int64
# ----------------------------------------
# DIC2:
# .................
# 2315.70    3
# 2315.50    2
# 2313.90    2
# 2014.00    2
# 2009.23    2
#           ..
# 2307.65    1
# 2349.59    1
# 2001.10    1
# 2011.50    1
# 2312.94    1
# Name: DIC2, Length: 216, dtype: int64
# ----------------------------------------
# TA1:
# .................
# 2233.40    5
# 2231.33    5
# 2230.80    4
# 2229.10    4
# 2237.03    4
#           ..
# 2181.57    1
# 2247.59    1
# 2245.98    1
# 2313.07    1
# 2305.96    1
# Name: TA1, Length: 1849, dtype: int64
# ----------------------------------------
# TA2:
# .................
# 2230.50    3
# 2318.32    2
# 2312.22    2
# 2228.57    2
# 2239.51    2
#           ..
# 2315.20    1
# 2238.40    1
# 2293.80    1
# 2221.64    1
# 2309.57    1
# Name: TA2, Length: 225, dtype: int64
# ----------------------------------------
# pH2:
# .................
# 7.9359    1
# 7.9883    1
# 7.9652    1
# 7.9501    1
# 7.9241    1
# 7.9231    1
# 7.9621    1
# 7.9300    1
# 7.9637    1
# 7.9432    1
# Name: pH2, dtype: int64
# ----------------------------------------
# pH1:
# .................
# 7.9100    2
# 7.9238    2
# 8.0477    1
# 7.9628    1
# 7.6665    1
#          ..
# 7.9633    1
# 7.8671    1
# 7.9442    1
# 7.9316    1
# 7.8738    1
# Name: pH1, Length: 82, dtype: int64
# ----------------------------------------
# DIC Quality Comment:
# .................
# CTD Bottle Misfire; DIC sample compromised.  CalCOFI Salt and oxygen values are from CTD.                                9
# stn changed to 86.7 45.0 was 86.7 40.0                                                                                   6
# Bottle tripped at correct depth                                                                                          4
# Depth changed to 170m was100m                                                                                            2
# Depth changed to 100m was 50m                                                                                            2
# DIC Salt contamination suspected                                                                                         1
# DIC Btl_ID 5442 moved to depth 320m was 230m                                                                             1
# DIC Bottle_ID 32 moved to 440m from 515                                                                                  1
# DIC Bottle_ID 5451 moved to 100m from 170m                                                                               1
# Depth changed to 171m from 230m                                                                                          1
# Depth changed to 230m from 320m                                                                                          1
# DIC Bottle_ID 75 moved to 40m was 50m                                                                                    1
# CalCOFI Salt replaced with CTD salt; DIC is from correct depth.  Oxy fine.                                               1
# Depth changed to 84m was 100m                                                                                            1
# DIC Bottle_ID 32 depth changed to 442m was a duplicate of 500m bottle                                                    1
# DIC Bottle_ID 109 depth changed to 439m from 500m                                                                        1
# DIC Bottle_ID 6941 depth changed to 30m from 50m                                                                         1
# CTD Bottle Misfire; DIC sample compromised. CalCOFI Salt and oxygen values are from CTD.                                 1
# CTD Niskin Bottom Cap Ajar; DIC sample compromised.  CalCOFI Salt and oxygen values are from CTD.                        1
# CTD Bottle Misfire; DIC sample compromised.  CalCOFI Salt and oxygen values are from CTD.  (orig salt was 34.006)        1
# Depth changed to 230m was 170m; DIC Bottle_ID 2940 also changed to this depth (was 320)                                  1
# Depth changed to 320m was 230m                                                                                           1
# DIC contamination suspected. Too high                                                                                    1
# DIC Bottle_ID 5018 moved to this depth; was at 170m                                                                      1
# Depth changed to 50m was 28m                                                                                             1
# Depth changed to 50m was 25m                                                                                             1
# Depth changed to 25m was 50m                                                                                             1
# Niskin lanyard crossed; DIC sample compromised.  CalCOFI Salt and oxygen values are from CTD.  (orig salt was 33.727)    1
# Depth changed to 170m was 230m                                                                                           1
# Depth changed to 60m not 50m                                                                                             1
# Depth changed to 40m not 30m                                                                                             1
# Depth changed to 170m from 230m                                                                                          1
# Depth changed to 230m from 170m                                                                                          1
# Depth changed to 45m not 57m                                                                                             1
# Depth changed to 271m from 320                                                                                           1
# Depth changed to 3500m from 515m                                                                                         1
# Depth changed to 270m was 232m                                                                                           1
# Name: DIC Quality Comment, dtype: int64
# ----------------------------------------

# %% [markdown]
# We need to perfrom two preprocessing steps: remove columns that are irrevelant for the correlation matrix and fill nan values in the rest. There are a number of columns that seem to be irrevelant (like bottle ID, cast count, bottle count, station ID etc.), and also some columns that have so many missing values (more than 60%) that estimation or replacement seems to be impractical. Technically the R values are not necessary neither, but leaving them does not cause harm. Will create bottle_dropped and cast_dropped dataframes:

# %%
bottle_dropped = bottle[[ 'Depthm', 'T_degC', 'Salnty', 'O2ml_L', 'STheta', 'O2Sat', 'Oxy_µmol/Kg',
       'RecInd', 'T_prec', 'S_prec', 'P_qual', 'Chlqua', 'Phaqua', 'PO4uM', 'PO4q', 'SiO3uM', 'SiO3qu', 'NO2uM', 'NO2q', 'NO3uM', 'NO3q',
       'NH3q', 'C14A1q', 'C14A2q', 'DarkAq', 'MeanAq', 'R_Depth', 'R_TEMP', 'R_POTEMP', 'R_SALINITY', 'R_SIGMA',
       'R_SVA', 'R_DYNHT', 'R_O2', 'R_O2Sat', 'R_SIO3', 'R_PO4', 'R_NO3',
       'R_NO2', 'R_PRES']]

from sklearn.impute import SimpleImputer
import numpy as np

imp = SimpleImputer(missing_values = np.nan, strategy = 'mean') # does it by columns
bottle_dropped_trans = pd.DataFrame(imp.fit_transform(bottle_dropped))
bottle_dropped_trans.columns = bottle_dropped.columns
bottle_dropped_trans.index = bottle_dropped.index

# %%
cast_dropped = cast[['Quarter', 'Distance', 'Lat_Dec', 'Lat_Deg', 'Lat_Min', 'Lon_Dec', 'Lon_Deg', 'Lon_Min', 'Rpt_Line',
       'St_Line', 'Ac_Line', 'Rpt_Sta', 'St_Station', 'Ac_Sta', 'Bottom_D','Order_Occ','Event_Num', 'Cruz_Leg', 'IntChl',
       'IntC14', 'Wave_Dir', 'Wave_Ht', 'Wave_Prd', 'Wind_Dir', 'Wind_Spd', 'Barometer',
       'Dry_T', 'Wet_T', 'Wea', 'Cloud_Typ', 'Cloud_Amt', 'Visibility']]

cast_dropped_trans = pd.DataFrame(imp.fit_transform(cast_dropped))
cast_dropped_trans.columns = cast_dropped.columns
cast_dropped_trans.index = cast_dropped.index

# %% [markdown]
# ### 2.	Perform feature selection (decide what columns should be included in your analysis). How did you figure out what features were important?

# %% [markdown]
# If we want to predict water temperature, we would look at features that show a strong positive or negative correlation. For this purpose we create a correlation matrix (see below).
#
# Strong negative correlations with water temperature: depth, salinity, Stheta, PO4, SiO3, NO3 miclomolar concentrations,
#
# Strong positive correlations with water temperature: oxygen content (well, this should be suspicious as gas solubility is higher at lower temperatures).

# %%
import matplotlib.pyplot as plt
import seaborn as sns

bottle_corr = bottle_dropped_trans.corr()
cast_corr = cast_dropped_trans.corr()

fig = plt.figure(figsize = (20, 25))
ax0 = fig.add_subplot(2, 1, 1) 
ax1 = fig.add_subplot(2, 1, 2)

fig.tight_layout(pad = 20.0)

sns.heatmap(bottle_corr, ax = ax0)
sns.heatmap(cast_corr, ax = ax1)

ax0.set_title('Correlation matrix for bottle data')
ax1.set_title('Correlation matrix for cast data')

plt.show()

# %% [markdown]
# ### 3.	Perform multiple linear regression on the dataset to predict water temperature. Be sure to display the final resulting equation with the coefficients and intercept in markdown.

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from statsmodels.formula.api import ols
import matplotlib.pyplot as plt
import numpy as np


X = bottle_dropped_trans[['Depthm', 'Salnty', 'O2ml_L', 'STheta', 'O2Sat', 'PO4uM', 'SiO3uM', 'NO3uM']]
y = bottle_dropped_trans[['T_degC']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

# ideally we would standardize features before regression, but I am not quite sure how to transform back in order to write the equation
# so while I perform the standardization below, the ftting I will do on the original data, the process is identical otherwise

sc = StandardScaler()
X_train_scaled = sc.fit_transform(X_train)
X_test_scaled = sc.fit_transform(X_test)

y_train_scaled = sc.fit_transform(y_train)
y_test_scaled = sc.fit_transform(y_test)

X_train_scaled_df = pd.DataFrame(X_train_scaled)
X_train_scaled_df.columns = X.columns

y_train_scaled_df = pd.DataFrame(y_train_scaled)
y_train_scaled_df.columns = y.columns

# %%
X_train
# Out:
#         Depthm    Salnty    O2ml_L     STheta       O2Sat     PO4uM  \
# 771657   100.0  33.09800  5.510000  25.013000   91.000000  0.650000
# 497132   100.0  33.93000  3.392468  26.220000   57.103779  1.564747
# 296595   351.0  34.33000  0.840000  26.722000   12.700000  1.564747
# 626145    10.0  33.84035  3.392468  25.819394   57.103779  1.564747
# 749690   300.0  34.07900  1.950000  26.570000   29.200000  2.390000
# ...        ...       ...       ...        ...         ...       ...
# 259178   400.0  34.21300  1.090000  26.722000   16.200000  1.564747
# 365838    28.0  33.58400  6.570000  25.231000  110.600000  1.564747
# 131932    50.0  33.54700  4.430000  25.247000   74.200000  1.564747
# 671155    60.0  33.24300  4.960000  25.157000   81.700000  0.960000
# 121958    69.0  33.24000  5.310000  25.819394   57.103779  1.564747
#
#            SiO3uM      NO3uM
# 771657   3.900000   4.200000
# 497132  26.606587  17.302247
# 296595  26.606587  17.302247
# 626145  26.606587  17.302247
# 749690  43.000000  32.200000
# ...           ...        ...
# 259178  26.606587  17.302247
# 365838  26.606587  17.302247
# 131932  26.606587  17.302247
# 671155   8.900000   7.900000
# 121958  26.606587  17.302247
#
# [605404 rows x 8 columns]

# %%
X_train_df = pd.DataFrame(X_train)
X_train_df.columns = X.columns

y_train_df = pd.DataFrame(y_train)
y_train_df.columns = y.columns

Xy_train_df = X_train_df.merge(y_train_df, left_index=True, right_index=True)

# %%
# it makes a sense to model temperature using salinity and oxygen on the one hand and the 3 anion concentrations on the other
# as they are incorporated in salinity anyways
# will try one model with implicit interaction, too

model_0 = ols('T_degC ~ Salnty + O2ml_L', data = Xy_train_df).fit()
model_1 = ols('T_degC ~ Salnty * O2ml_L', data = Xy_train_df).fit()
model_2 = ols('T_degC ~ PO4uM + SiO3uM + NO3uM', data = Xy_train_df).fit()

# %%
print(model_0.params)
# Out:
# Intercept   -11.191970
# Salnty        0.479341
# O2ml_L        1.699887
# dtype: float64

# %% [markdown]
# This would give df['T_degC'] = -11.19 + 0.48*df['Salnty'] + 1.69*df['O2ml_L']

# %%
print(model_1.params)
# Out:
# Intercept        8.060130
# Salnty          -0.085099
# O2ml_L          -3.039242
# Salnty:O2ml_L    0.139458
# dtype: float64

# %% [markdown]
# This would give df['T_degC'] = 8.06 - 0.085*df['Salnty'] - 3.039*df['O2ml_L'] + 0.139*df['Salnty']*df['O2ml_L']

# %%
print(model_2.params)
# Out:
# Intercept    16.357570
# PO4uM        -3.377256
# SiO3uM        0.000685
# NO3uM        -0.017193
# dtype: float64

# %% [markdown]
# This would give df['T_degC'] = 16.35 - 3.37*df['PO4uM'] + 0.0007*df['SiO3uM'] - 0.017*df['NO3uM']

# %% [markdown]
# ### 4.	Which regression approach had the “best” performance? Be sure to compare it to what you did last week.

# %%
y_pred_0 = model_0.predict(X_test)
y_pred_1 = model_1.predict(X_test)
y_pred_2 = model_2.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

r2_ = r2_score(y_test, y_pred_0) 
mse = mean_squared_error(y_test, y_pred_0)

print("Linear regression R squared for correlation of temperature, salinity and oxygen: {}".format(r2_))
print("Linear regression MSE: {}".format(mse))
# Out:
# Linear regression R squared for correlation of temperature, salinity and oxygen: 0.5085660612753584
# Linear regression MSE: 8.735252412761982

# %%
r2_ = r2_score(y_test, y_pred_1) 
mse = mean_squared_error(y_test, y_pred_1)

print("Linear regression R squared for correlation of temperature, salinity and oxygen: {}".format(r2_))
print("Linear regression MSE: {}".format(mse))
# Out:
# Linear regression R squared for correlation of temperature, salinity and oxygen: 0.5091553543203846
# Linear regression MSE: 8.72477771191664

# %%
r2_ = r2_score(y_test, y_pred_2)
mse = mean_squared_error(y_test, y_pred_2)

print("Linear regression R squared for correlation of temperature and anion concentration: {}".format(r2_))
print("Linear regression MSE: {}".format(mse))
# Out:
# Linear regression R squared for correlation of temperature and anion concentration: 0.36541147343667635
# Linear regression MSE: 11.279829334048783

# %% [markdown]
# All of these perform better than the 'simple' linear regression from last week. The cause behind this might be that as we saw last week, the relationship between temperature and other variables is not linear so the fit there is quite poor, but here we force multiple linear realtionships on the model, and generally more parameters improve the metrics.

# %% [markdown]
# ### 5.	Work with the diabetes dataset to perform multiple logistic regression.

# %%
diabetes_path = 'C:/Users/balazs.varga/Documents/BALAZS/USE/REPOS/HW/WEEK13/diabetes.csv'
diabetes = pd.read_csv(diabetes_path)

diabetes.head(2)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0

# %%
X = diabetes.drop(columns = ['Outcome'], axis = 1)
y = diabetes['Outcome']

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=42, stratify=y)

X_train_df = pd.DataFrame(X_train)
X_train_df.columns = X.columns

X_test_df = pd.DataFrame(X_test)
X_test_df.columns = X.columns

y_train_df = pd.DataFrame(y_train)
y_train_df.columns = diabetes[['Outcome']].columns

Xy_train_df = X_train_df.merge(y_train_df, left_index=True, right_index=True)

# %%
# we can do LogisticRegression from sklearn
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(random_state=42)
model.fit(X_train, y_train)

#calculate accuracy
from sklearn.metrics import balanced_accuracy_score
y_pred_logistic = model.predict(X_test)
balanced_accuracy_score(y_test, y_pred)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.6859259259259259

# %%
# or we can use logit from statsmodels
from statsmodels.formula.api import logit

diabetes_model = logit('Outcome ~ Pregnancies + Glucose + BloodPressure + SkinThickness + Insulin + BMI + DiabetesPedigreeFunction + Age + 0', data = Xy_train_df).fit()
diabetes_model.params
# Out:
# Optimization terminated successfully.
#          Current function value: 0.605610
#          Iterations 5
# Pregnancies                 0.128200
# Glucose                     0.012823
# BloodPressure              -0.028404
# SkinThickness              -0.007643
# Insulin                     0.001918
# BMI                         0.000517
# DiabetesPedigreeFunction    0.098557
# Age                        -0.019439
# dtype: float64

# %%
from sklearn.metrics import accuracy_score

y_pred_logit = np.round(diabetes_model.predict(X_test))

print('Test accuracy score = ', accuracy_score(y_test, y_pred))
print('Test accuracy (balanced)= ', balanced_accuracy_score(y_test, y_pred))
# Out:
# Test accuracy score =  0.7359307359307359
# Test accuracy (balanced)=  0.6859259259259259

# %% [markdown]
# ### 6.	What are the other ways to assess the performance of the model besides accuracy? What approach makes the most sense with the diabetes dataset? Why?

# %%
# we can look at recall that gives us an understanding of how good we are detecting the positives
# this makes more sense since it is much more important to diagnise positives correctly, than negatives in the first round
# we can access it with other metrics from classification_report or classification_report_imbalanced
# the method of calculating it is the same, so both reports give the same result

from imblearn.metrics import classification_report_imbalanced
from sklearn.metrics import classification_report
print(classification_report_imbalanced(y_test, y_pred_logistic))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.77      0.86      0.52      0.81      0.67      0.46       150
#           1       0.67      0.52      0.86      0.58      0.67      0.43        81
#
# avg / total       0.73      0.74      0.64      0.73      0.67      0.45       231

# %%
print(diabetes_model.summary())
# Out:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                Outcome   No. Observations:                  537
# Model:                          Logit   Df Residuals:                      529
# Method:                           MLE   Df Model:                            7
# Date:                Sat, 08 Jan 2022   Pseudo R-squ.:                 0.06302
# Time:                        01:46:46   Log-Likelihood:                -325.21
# converged:                       True   LL-Null:                       -347.09
# Covariance Type:            nonrobust   LLR p-value:                 2.390e-07
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Pregnancies                  0.1282      0.034      3.755      0.000       0.061       0.195
# Glucose                      0.0128      0.003      3.835      0.000       0.006       0.019
# BloodPressure               -0.0284      0.006     -5.109      0.000      -0.039      -0.018
# SkinThickness               -0.0076      0.008     -0.994      0.320      -0.023       0.007
# Insulin                      0.0019      0.001      1.771      0.077      -0.000       0.004
# BMI                          0.0005      0.013      0.040      0.968      -0.025       0.026
# DiabetesPedigreeFunction     0.0986      0.288      0.342      0.732      -0.466       0.663
# Age                         -0.0194      0.010     -1.951      0.051      -0.039    9.07e-05
# ============================================================================================

# %%
print(classification_report(y_test, y_pred_logit))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.83      0.77       150
#            1       0.57      0.42      0.48        81
#
#     accuracy                           0.68       231
#    macro avg       0.65      0.62      0.63       231
# weighted avg       0.67      0.68      0.67       231

# %%
print(classification_report_imbalanced(y_test, y_pred_logit))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.73      0.83      0.42      0.77      0.59      0.36       150
#           1       0.57      0.42      0.83      0.48      0.59      0.33        81
#
# avg / total       0.67      0.68      0.56      0.67      0.59      0.35       231

# %% [markdown]
# ### 7.	Tune your model to improve performance based on the performance metric you identified in question 6. Look at the documentation for logistic regression in statsmodel and/or sklearn and see if you can tune the model performance based on available parameters. Please note: data scientists need to constantly learn new approaches to optimizing models. This is one way of doing that.

# %%
# we can standardize the data, that should make an improvement
sc = StandardScaler()
X_train_scaled = sc.fit_transform(X_train)
X_test_scaled = sc.fit_transform(X_test)

model.fit(X_train_scaled, y_train)

#calculate accuracy
y_pred_trans_logistic = model.predict(X_test_scaled)
balanced_accuracy_score(y_test, y_pred_trans_logistic)
# Out:
# 0.6859259259259259

# %% [markdown]
# The effect of this was marginal...

# %%
print(classification_report_imbalanced(y_test, y_pred_trans_logistic))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.77      0.85      0.52      0.81      0.67      0.46       150
#           1       0.66      0.52      0.85      0.58      0.67      0.43        81
#
# avg / total       0.73      0.74      0.64      0.73      0.67      0.45       231

# %%
# we can do hyperparameter optimization
# for logistic regression it is the c parameter
# GridSearchCV implements train_test_split already

from sklearn.model_selection import GridSearchCV

c_space = np.logspace(-5, 8, 15)
param_grid = {'C' : c_space}

logreg_cv = GridSearchCV(model, param_grid, cv = 5, scoring = 'recall')
logreg_cv.fit(X, y)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# GridSearchCV(cv=5, estimator=LogisticRegression(random_state=42),
#              param_grid={'C': array([1.00000000e-05, 8.48342898e-05, 7.19685673e-04, 6.10540230e-03,
#        5.17947468e-02, 4.39397056e-01, 3.72759372e+00, 3.16227766e+01,
#        2.68269580e+02, 2.27584593e+03, 1.93069773e+04, 1.63789371e+05,
#        1.38949549e+06, 1.17876863e+07, 1.00000000e+08])},
#              scoring='recall')

# %%
print(f'Tuned Logistic Regression Parameters: {logreg_cv.best_params_}') 
print(f'Best score is {logreg_cv.best_score_}')
# Out:
# Tuned Logistic Regression Parameters: {'C': 31.622776601683793}
# Best score is 0.5783368273934312

# %%
best_logistic = LogisticRegression(C = 31.622776601683793)

best_logistic.fit(X_train, y_train)
y_pred = best_logistic.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.86      0.81       150
#            1       0.67      0.52      0.58        81
#
#     accuracy                           0.74       231
#    macro avg       0.72      0.69      0.70       231
# weighted avg       0.73      0.74      0.73       231
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# we can plot the ROC curve for the best model:

from sklearn.metrics import roc_curve
y_pred_prob = best_logistic.predict_proba(X_test)[:, 1]
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
_= plt.plot([0, 1], [0, 1], 'k--')
_= plt.plot(fpr, tpr, label = 'Logistic Regression')
_= plt.xlabel('False Positive Rate')
_= plt.ylabel('True Positive Rate')
_= plt.title('Logistic Regression ROC Curve')
plt.show()

# %% [markdown]
# ### 8.	Is the KNN model or the multiple logistic regression model more performant for the diabetes dataset? How can you tell?

# %%
# in knn it is the hyperparameter is n_neighbors parameter

from sklearn.neighbors import KNeighborsClassifier

param_grid = {'n_neighbors' : np.arange(1, 20)}
knn = KNeighborsClassifier()
knn_cv = GridSearchCV(knn, param_grid, cv = 5, scoring = 'recall')
knn_cv.fit(X, y)
knn_cv.best_params_
# Out:
# {'n_neighbors': 3}

# %%
knn_optimal = KNeighborsClassifier(n_neighbors = 3)
knn_optimal.fit(X_train, y_train)
y_pred = knn_optimal.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.82      0.78       150
#            1       0.60      0.49      0.54        81
#
#     accuracy                           0.71       231
#    macro avg       0.67      0.66      0.66       231
# weighted avg       0.70      0.71      0.70       231

# %% [markdown]
# The recall of positives is better for the optimized LogisticRegression, but the difference might not be significant (0.52 vs 0.49)

# %% [markdown]
# ![Toolbox%202.png](attachment:Toolbox%202.png)
